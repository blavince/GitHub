# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![標準動作](3-05.standardcommand.png)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3, -4, 1, 5, -2, 7, 3, -5, 6])

# %%
plt.plot(np.random.randn(100))
